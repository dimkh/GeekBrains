# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

count = 200000
x = np.random.randint(0,37,count)
num_bins = 37
n, bins, patches = plt.hist(x, num_bins)
plt.xlabel('Выпало число')
plt.ylabel('Количество выпадений')
plt.title(f'Рулетка, {count} испытаний')
plt.show()
