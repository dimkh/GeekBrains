# %% [markdown]
# **Подключение библиотек и скриптов**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Пути к директориям и файлам**

# %%
DATASET_PATH = 'housing.csv'
PREPARED_DATASET_PATH = 'housing_prepared.csv'

# %% [markdown]
# ## **Загрузка данных**

# %% [markdown]
# **Описание датасета**
#
# Статистические данные о ряде домов в Калифорнии, основанные на переписи 1990 года.
#
# * **longitude** - долгота
# * **latitude** - широта
# * **housing_median_age** - средний возраст дома
# * **total_rooms** - общее количество комнат
# * **total_bedrooms** - общее количество спален
# * **population** - количество проживающих
# * **households** - домохозяйства
# * **median_income** - средний доход
# * **median_house_value** - средняя стоимость дома
# * **ocean_proximity** - близость океана

# %% [markdown]
# Считываем датасет и выводим первые пять строк для проверки.

# %%
ds_house = pd.read_csv(DATASET_PATH, sep = ',')
ds_house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    id
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4

# %% [markdown]
# Посмотрим общее описание датасета и проанализируем признаки.

# %%
ds_house.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        19918.000000  20640.000000
# mean    -119.471242     35.036934           28.653630   2635.763081
# std        5.041408     94.903955           12.576796   2181.615252
# min     -124.350000 -13534.030000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max      122.030000   1327.130000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20041.000000  20640.000000   20640.000000
# mean       537.870553   1425.418243    499.539680       3.870671
# std        421.385070   1135.185798    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    786.000000    280.000000       2.563400
# 50%        435.000000   1165.000000    409.000000       3.534800
# 75%        647.000000   1726.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value            id
# count        20640.000000  20640.000000
# mean        206855.816909  10319.500000
# std         115395.615874   5958.399114
# min          14999.000000      0.000000
# 25%         119600.000000   5159.750000
# 50%         179700.000000  10319.500000
# 75%         264725.000000  15479.250000
# max         500001.000000  20639.000000

# %% [markdown]
# Можно сделать несколько предварительных выводов:
# 1. Не все признаки датасета заполнены: всего 20640 объектов, а, например, количество признаков 'total_bedrooms' и 'population' -
# 20433 и 20041 соответственно. Значит, какие-то значения пропущены и эти пропуски нужно будет отработать.
# 2. Минимальные и максимальные значения долготы и широты (по сравнению со средним и квантилями) говорят о том, что имеем артефакты,
# которые тоже нужно будет обработать.

# %% [markdown]
# **Обработка пропусков**

# %% [markdown]
# В каких признаках и сколько пропусков.

# %%
len(ds_house) - ds_house.count()
# Out:
# longitude               0
# latitude                0
# housing_median_age    722
# total_rooms             0
# total_bedrooms        207
# population            599
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# id                      0
# dtype: int64

# %% [markdown]
# Заполняем пропуски медианным значением соответствующего признака (медиана устойчивее прочих способов).
#
# Считаю неверным заполнять "total_bedrooms" медианным значением (т.к. получим результат типа "всего комнат в доме - 154,
# из них спален - 435). Нулевых значений в признаке нет, поэтому пока заполню нулями. Дальше обработаю иным способом.
#
# По этой же причине нельзя заполнять медианным значением признак "population", т.к. можем получить "1165 человек в 5 комнатах".
# Аналогичный расчёт ниже.

# %%
median = ds_house['housing_median_age'].median()
ds_house['housing_median_age'].fillna(median, inplace = True)

ds_house['total_bedrooms'].fillna(0, inplace = True)

ds_house['population'].fillna(0, inplace = True)

# %% [markdown]
# **Обработка номинативного признака**

# %%
ds_house['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9127
# INLAND        6542
# NEAR OCEAN    2655
# NEAR BAY      2288
# -               23
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# 23 пропущенных значения заменяем модой.

# %%
ds_house.replace({'ocean_proximity': {'-': ds_house['ocean_proximity'].mode()[0]}}, inplace = True)

# %% [markdown]
# ## **Обработка выбросов**

# %% [markdown]
# California City находится в северном и западном полушарии и имеет координаты:
# широта: 35.1258000
# долгота: -117.9859000

# %%
ds_house[ds_house['longitude'] >= 0]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3479      118.51     34.29                29.0       1287.0           194.0
# 5904      118.43     34.29                39.0       1769.0           410.0
# 8405      118.36     33.93                40.0       1625.0           500.0
# 8636      118.41     33.88                43.0       2492.0           449.0
# 13051     121.29     38.61                17.0      13553.0          2474.0
# 15263     117.27     33.02                21.0       2144.0           340.0
# 17085       0.00     37.47                33.0       1266.0           415.0
# 17359       0.00     34.88                 4.0       3680.0           559.0
# 18551     122.03     36.96                28.0       1607.0           421.0
# 19423       0.00     37.69                 5.0       9601.0          1639.0
#
#        population  households  median_income  median_house_value  \
# 3479        525.0       187.0         6.4171            319300.0
# 5904       1499.0       390.0         3.1212            153500.0
# 8405       2036.0       476.0         2.6298            156500.0
# 8636       1033.0       437.0         7.9614            500001.0
# 13051      6544.0      2359.0         3.9727            132700.0
# 15263       928.0       344.0         5.7980            286100.0
# 17085      1991.0       334.0         2.9200            202800.0
# 17359      1678.0       569.0         5.0639            201700.0
# 18551       926.0       385.0         2.4250            216100.0
# 19423      4449.0      1575.0         4.5332            195500.0
#
#       ocean_proximity     id
# 3479        <1H OCEAN   3479
# 5904        <1H OCEAN   5904
# 8405        <1H OCEAN   8405
# 8636        <1H OCEAN   8636
# 13051          INLAND  13051
# 15263      NEAR OCEAN  15263
# 17085      NEAR OCEAN  17085
# 17359       <1H OCEAN  17359
# 18551      NEAR OCEAN  18551
# 19423          INLAND  19423

# %% [markdown]
# Видно, что либо потерян минус, либо долгота неизвестна. Заменяем ноль медианным значением.

# %%
ds_house.loc[ds_house['longitude'] > 0, 'longitude'] = ds_house.loc[ds_house['longitude'] > 0, 'longitude'] * -1
ds_house.loc[ds_house['longitude'] == 0, 'longitude'] = ds_house['longitude'].median()

# %% [markdown]
# Аналогично обработаем широту: корректные значение широты должны быть 35 плюс-минус несколько градусов.

# %%
ds_house[(ds_house['latitude'] <= 0) | (ds_house['latitude'] > 50)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8283     -118.13 -13534.03                45.0       1016.0           172.0
# 12772    -121.42   1327.13                29.0       2217.0           536.0
#
#        population  households  median_income  median_house_value  \
# 8283        361.0       163.0         7.5000            434500.0
# 12772      1203.0       507.0         1.9412             73100.0
#
#       ocean_proximity     id
# 8283       NEAR OCEAN   8283
# 12772          INLAND  12772

# %%
ds_house.loc[(ds_house['latitude'] <= 0) | (ds_house['latitude'] > 50), 'latitude'] = ds_house['latitude'].median()

# %% [markdown]
# Исключаем ненужный признак id

# %%
ds_house.drop(columns = 'id', inplace = True)

# %% [markdown]
# Преобразуем категориальный признак "oceans_proximity" в несколько бинарных

# %%
ds_house = pd.concat([ds_house, pd.get_dummies(ds_house['ocean_proximity'])], axis = 1)
ds_house.drop(columns = 'ocean_proximity', inplace = True)

# %% [markdown]
# Рассчитаем дополнительные параметры:

# %%
# Доля спален в общем количестве комнат
ds_house['bedroom_share'] = ds_house['total_bedrooms'] / ds_house['total_rooms'] * 100

# Сколько человек в срелнем в одном домохозяйстве
ds_house['men_per_household'] = ds_house['population'] / ds_house['households']

# %% [markdown]
# И вот только сейчас заполняем пропуски признака "total_bedrooms", рассчитывая их количество через медианное значение доли спален.

# %%
median = ds_house[ds_house['bedroom_share'] > 0].median()['bedroom_share']
ds_house.loc[(ds_house['bedroom_share'] == 0), 'total_bedrooms'] = round(median * ds_house['total_rooms'])
ds_house.loc[(ds_house['bedroom_share'] == 0), 'bedroom_share'] = ds_house['total_bedrooms'] / ds_house['total_rooms'] * 100

# %% [markdown]
# Аналогично рассчитываем пропуски признака "population" через медианное значение человек в домохозяйстве.

# %%
median = ds_house[ds_house['men_per_household'] > 0].median()['men_per_household']
ds_house.loc[(ds_house['men_per_household'] == 0), 'population'] = round(median * ds_house['households'])
ds_house.loc[(ds_house['men_per_household'] == 0), 'men_per_household'] = ds_house['population'] / ds_house['households']

# %%
# Сколько человек в среднем живут в одной комнате
ds_house['population_per_room'] = ds_house['population'] / ds_house['total_rooms']

# %%
ds_house.nlargest(10, 'population_per_room')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16420    -121.29     37.89                26.0        161.0            27.0
# 19435    -121.04     37.67                16.0         19.0            19.0
# 12104    -117.33     33.97                 8.0        152.0            19.0
# 20352    -119.09     34.22                 8.0         40.0            10.0
# 15790    -122.40     37.77                52.0        144.0            63.0
# 13366    -117.63     33.94                36.0        447.0            95.0
# 16643    -120.65     35.32                20.0        626.0           212.0
# 8874     -118.45     34.06                52.0        204.0            34.0
# 19524    -121.00     37.64                19.0        121.0            41.0
# 4861     -118.28     34.02                29.0        515.0           229.0
# 5986     -117.71     34.10                52.0        567.0           152.0
# 91       -122.28     37.80                52.0        215.0            87.0
# 14756    -116.97     32.56                23.0       1262.0           294.0
# 270      -122.18     37.78                33.0        142.0            31.0
# 2899     -119.01     35.37                35.0        120.0            35.0
# 4479     -118.16     34.07                41.0        247.0            55.0
# 12649    -121.47     38.51                52.0         20.0             4.0
# 16672    -120.69     35.34                16.0        164.0            30.0
# 7164     -118.17     34.06                36.0        871.0           201.0
# 4587     -118.27     34.05                37.0        350.0           245.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 16420      1542.0        30.0         5.7485            162500.0          0
# 19435       166.0         9.0         0.5360            162500.0          0
# 12104      1275.0        20.0         1.6250            162500.0          0
# 20352       309.0        16.0         4.0208             52500.0          0
# 15790      1061.0        68.0         4.3958            225000.0          0
# 13366      2886.0        85.0         4.2578            183300.0          0
# 16643      3574.0       261.0         1.0298            300000.0          0
# 8874       1154.0        28.0         9.3370            500001.0          1
# 19524       658.0        41.0         0.9573            162500.0          0
# 4861       2690.0       217.0         0.4999            500001.0          1
# 5986       2688.0       126.0         1.8750            212500.0          0
# 91          904.0        88.0         0.8668            137500.0          0
# 14756      5176.0       275.0         2.5625            153300.0          0
# 270         575.0        47.0         3.8750            225000.0          0
# 2899        477.0        41.0         1.9125             47500.0          0
# 4479        925.0        50.0         3.5769            135700.0          1
# 12649        74.0         9.0         3.6250             80000.0          0
# 16672       542.0        32.0         1.6563             42500.0          0
# 7164       2862.0       181.0         2.1845            123800.0          1
# 4587       1122.0       248.0         2.7634            137500.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_share  men_per_household  \
# 16420       1       0         0           0      16.770186          51.400000
# 19435       1       0         0           0     100.000000          18.444444
# 12104       1       0         0           0      12.500000          63.750000
# 20352       0       0         0           1      25.000000          19.312500
# 15790       0       0         1           0      43.750000          15.602941
# 13366       1       0         0           0      21.252796          33.952941
# 16643       0       0         0           1      33.865815          13.693487
# 8874        0       0         0           0      16.666667          41.214286
# 19524       1       0         0           0      33.884298          16.048780
# 4861        0       0         0           0      44.466019          12.396313
# 5986        1       0         0           0      26.807760          21.333333
# 91          0       0         1           0      40.465116          10.272727
# 14756       0       0         0           1      23.296355          18.821818
# 270         0       0         1           0      21.830986          12.234043
# 2899        1       0         0           0      29.166667          11.634146
# 4479        0       0         0           0      22.267206          18.500000
# 12649       1       0         0           0      20.000000           8.222222
# 16672       0       0         0           1      18.292683          16.937500
# 7164        0       0         0           0      23.076923          15.812155
# 4587        0       0         0           0      70.000000           4.524194
#
#        population_per_room  age_cat
# 16420             9.577640        4
# 19435             8.736842        3
# 12104             8.388158        2
# 20352             7.725000        2
# 15790             7.368056        4
# 13366             6.456376        4
# 16643             5.709265        3
# 8874              5.656863        4
# 19524             5.438017        3
# 4861              5.223301        4
# 5986              4.740741        4
# 91                4.204651        4
# 14756             4.101426        3
# 270               4.049296        4
# 2899              3.975000        4
# 4479              3.744939        4
# 12649             3.700000        4
# 16672             3.304878        3
# 7164              3.285878        4
# 4587              3.205714        4

# %% [markdown]
# Видно, что 5 объектов с максимальным количеством человек на комнату сильно выбиваются из оставшегося ряда.
# Делаю вывод, что это какие-то ошибочные значения (либо какие-то производственные помещения), которые для построения модели не нужны. Удаляю их.

# %%
ds_house = ds_house.loc[ds_house['population_per_room'] < 10]

# %% [markdown]
# Разделим дома по возрасту на категории.

# %%
def age_to_cat(X):

    X['age_cat'] = 0

    X.loc[X['housing_median_age'] <= 5, 'age_cat'] = 1
    X.loc[(X['housing_median_age'] > 5) & (X['housing_median_age'] <= 10), 'age_cat'] = 2
    X.loc[(X['housing_median_age'] > 10) & (X['housing_median_age'] <= 25), 'age_cat'] = 3
    X.loc[X['housing_median_age'] > 25, 'age_cat'] = 4

    return X

# %%
ds_house = age_to_cat(ds_house)

# %%
ds_house.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20635.000000  20635.000000        20635.000000  20635.000000
# mean    -119.569061     35.631234           28.663775   2636.355658
# std        2.003559      2.135649           12.353131   2181.545323
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           19.000000   1448.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20635.000000  20635.000000  20635.000000   20635.000000
# mean      1054.861885   1423.653986    499.652968       3.870136
# std       6301.122420   1130.960762    382.306343       1.899433
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    786.000000    280.000000       2.562500
# 50%        438.000000   1165.000000    409.000000       3.534500
# 75%        657.000000   1724.000000    605.000000       4.742600
# max     237883.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value     <1H OCEAN        INLAND        ISLAND  \
# count        20635.000000  20635.000000  20635.000000  20635.000000
# mean        206860.647492      0.443421      0.316840      0.000242
# std         115399.563575      0.496801      0.465256      0.015565
# min          14999.000000      0.000000      0.000000      0.000000
# 25%         119600.000000      0.000000      0.000000      0.000000
# 50%         179700.000000      0.000000      0.000000      0.000000
# 75%         264750.000000      1.000000      1.000000      0.000000
# max         500001.000000      1.000000      1.000000      1.000000
#
#            NEAR BAY    NEAR OCEAN  bedroom_share  men_per_household  \
# count  20635.000000  20635.000000   20635.000000       20635.000000
# mean       0.110880      0.128616      41.470776           2.938384
# std        0.313991      0.334783     200.424073           1.078783
# min        0.000000      0.000000      10.000000           0.750000
# 25%        0.000000      0.000000      17.570616           2.440954
# 50%        0.000000      0.000000      20.371669           2.817620
# 75%        0.000000      0.000000      24.124533           3.263586
# max        1.000000      1.000000    2031.818182          63.750000
#
#        population_per_room       age_cat
# count         20635.000000  20635.000000
# mean              0.589361      3.498280
# std               0.297179      0.706342
# min               0.018109      1.000000
# 25%               0.436170      3.000000
# 50%               0.516425      4.000000
# 75%               0.654531      4.000000
# max               9.577640      4.000000

# %% [markdown]
# Проверим строки с большим общим количеством комнат - выглядят подозрительно.

# %%
ds_house.nlargest(10, "total_rooms")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13139    -121.44     38.43                29.0      39320.0          6210.0
# 10309    -117.74     33.89                 4.0      37937.0          5471.0
# 9880     -121.79     36.64                11.0      32627.0          6445.0
# 6057     -117.78     34.03                 8.0      32054.0          5290.0
# 12201    -117.20     33.58                 2.0      30450.0          5033.0
# 9019     -118.78     34.16                 9.0      30405.0          4093.0
# 12215    -117.12     33.52                 4.0      30401.0          4957.0
# 922      -121.92     37.53                 7.0      28258.0          3864.0
# 12623    -121.53     38.48                 5.0      27870.0          5027.0
# 6066     -117.87     34.04                 7.0      27700.0          4179.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13139     16305.0      5358.0         4.9516            153700.0          0
# 10309     16122.0      5189.0         7.4947            366300.0          1
# 9880      28566.0      6082.0         2.3087            118800.0          1
# 6057      15507.0      5050.0         6.0191            253900.0          1
# 12201      9419.0      3197.0         4.5936            174300.0          1
# 9019      12873.0      3931.0         8.0137            399200.0          0
# 12215     13251.0      4339.0         4.5841            212300.0          1
# 922       12203.0      3701.0         8.4045            451100.0          1
# 12623     11935.0      4855.0         4.8811            212200.0          0
# 6066      15037.0      4072.0         6.6288            339700.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_share  men_per_household  \
# 13139       1       0         0           0      15.793489           3.043113
# 10309       0       0         0           0      14.421277           3.106957
# 9880        0       0         0           0      19.753578           4.696810
# 6057        0       0         0           0      16.503401           3.070693
# 12201       0       0         0           0      16.528736           2.946200
# 9019        0       0         0           1      13.461602           3.274739
# 12215       0       0         0           0      16.305385           3.053929
# 922         0       0         0           0      13.674004           3.297217
# 12623       1       0         0           0      18.037316           2.458290
# 6066        0       0         0           0      15.086643           3.692780
#
#        population_per_room  age_cat
# 13139             0.414674        4
# 10309             0.424968        1
# 9880              0.875533        3
# 6057              0.483777        2
# 12201             0.309327        1
# 9019              0.423384        2
# 12215             0.435874        1
# 922               0.431842        2
# 12623             0.428238        1
# 6066              0.542852        2

# %% [markdown]
# Количество человек на комнату не превышает средних значений, в среднем 3 человека в домохозяйстве (семье), зато количество спален очень мало.
# С учётом большого количества комнат делаю вывод, что это здания типа наших общежитий, где проживают семьи с одним ребенком, а не ошибочные данные.

# %% [markdown]
# **Сохранение результатов**

# %%
ds_house.to_csv(PREPARED_DATASET_PATH, index = False, encoding = 'utf-8')
