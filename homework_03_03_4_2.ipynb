# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-200, 0, 201)
plt.plot(x, (np.exp(x) + x - 1)/x)

plt.plot([-200,0],[1,1], color ='red', linewidth=0.75, linestyle ="--") 
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(0,2) 
plt.grid(True)
plt.show()
