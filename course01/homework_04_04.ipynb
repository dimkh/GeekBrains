# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

a1 = 0.01
a2 = 0.02
m1 = 100
m2 = 500

x = np.linspace(a1*m1-1, a2*m2+1, 201)
plt.plot(x, np.sin(x))
# Рисуем ноль (ось х) и рассчитанный интервал
plt.plot([a1*m1-1,a2*m2+1],[0,0], color ='red', linewidth=0.75, linestyle ="--") 
plt.plot([a1*m1,a1*m1],[-1,1], color ='black', linewidth=1.75, linestyle ="--") 
plt.plot([a2*m2,a2*m2],[-1,1], color ='black', linewidth=1.75, linestyle ="--") 
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.title('График функции y = sin(a*x)')
plt.show()

def equations(p):
    x = p
    return np.sin(x)

x1 = fsolve(equations, 3)
x2 = fsolve(equations, 6)
x3 = fsolve(equations, 9)
print (x1)
print (x2)
print (x3)
# Out:
# [3.14159265]
# [6.28318531]
# [9.42477796]
